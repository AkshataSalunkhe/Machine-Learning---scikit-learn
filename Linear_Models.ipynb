# %% [markdown]
# # Linear Models

# %% [markdown]
# ### 1.1 Oridaniry Least Squared
#
# -- Linear regression fits a linear model with coefficients w =(w1, w2, ....) to minimize the residual sum of squares between the observed targets in the dataset, and the targets predicted by the linear approximation.
#
# -- Limitation : Data is evenly districuted and no ooutliers are present in data then OLS works fine otherwise it won't

# %%
from sklearn  import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.5, 0.5])

# %% [markdown]
# ### Linear Regression example

# %%
# import required libraries 
import numpy as np
import pandas as pd 
from sklearn import linear_model
from sklearn import datasets
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
diabetes_X[:, np.newaxis, 2]
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# %%
# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# %%
reg = linear_model.LinearRegression()
reg.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
diabetes_y_pred = reg.predict(diabetes_X_test)

# %%
# Print the coefficient of the model 
print('COefficient:', reg.coef_)
print ('MAE:', mean_squared_error(diabetes_y_test, diabetes_y_pred))
print('Rscore: ', r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# COefficient: [ 3.06094248e-01 -2.37635570e+02  5.10538048e+02  3.27729878e+02
#  -8.14111926e+02  4.92799595e+02  1.02841240e+02  1.84603496e+02
#   7.43509388e+02  7.60966464e+01]
# MAE: 2004.5186863342092
# Rscore:  0.585085427447195

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.2 Non negative least squeared
#
# -- Data is non negative format like price of woods, length or data in boolean format True/ false
#
# Syntax :
# reg = LinearRegression(positive=True)

# %% [markdown]
# ## 1.3 Ridge regression
#
# -- Ridge Regression, a technique in linear regression, is designed to handle scenarios where predictor variables exhibit high collinearity or strong correlation.
